# %%
import pandas as pd

# %%
df = pd.read_csv("ForManualEval.tsv",sep='\t')

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1      id  \
# 0           0             0  163896
# 1           1             1  143206
# 2           2             2    1605
# 3           3             3   69263
# 4           4             4  212657
#
#                                      title_orig_case                   source  \
# 0  Is This Going To Make Me A Different Person? G...  AllTheNewsComponentsOne
# 1   Rio has turned Hope Solo into public enemy No. 1  AllTheNewsComponentsOne
# 2  WHO says new drugs urgently needed to fight su...                  Harvard
# 3  A top investor nails why Microsoft is getting ...  AllTheNewsComponentsOne
# 4  As he moves campaign to battlegrounds, which D...         AllTheNewsKaggle
#
#                                             headline  \
# 0  Is this going to make me a different person? g...
# 1   Rio has turned hope solo into public enemy no. 1
# 2  Who says new drugs urgently needed to fight Su...
# 3  A top investor nails why Microsoft is getting ...
# ...

# %%
df1 = df[['title_orig_case','predicted']]

# %%
df1 = df1.rename({"title_orig_case":"original_clean",
                 "predicted":"edited_version"},axis=1)

# %%
df1
# Out:
#                                         original_clean  \
# 0    Is This Going To Make Me A Different Person? G...
# 1     Rio has turned Hope Solo into public enemy No. 1
# 2    WHO says new drugs urgently needed to fight su...
# 3    A top investor nails why Microsoft is getting ...
# 4    As he moves campaign to battlegrounds, which D...
# ..                                                 ...
# 195  Uber: We're 'absolutely not' behind smear camp...
# 196  Every Day, 7,000 Americans Try Weed for the Fi...
# 197    Marshawn Lynch is reportedly planning to retire
# 198  Bible charity vows to continue translation wor...
# 199  As Trump Lifestyle Takes Toll On Secret Servic...
#
#                                         edited_version
# 0    Is this going to make me a different person ? ...
# 1    Rio has turned hope solo into public enemy chi...
# 2    Who says new drugs urgently going to fight Sup...
# 3    A top investor nails microsoft Microsoft is ge...
# ...

# %%
df1.to_csv('my_data.csv')
