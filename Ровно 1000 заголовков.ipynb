# %%
import pandas as pd

# %%
from tqdm import tqdm

# %%
df = pd.read_excel("unsupervised_news_truecased.xlsx", engine="openpyxl").dropna(subset=["title_true_case"])

# %%
len(df)
# Out:
# 360637

# %%
df.head()
# Out:
#    Unnamed: 0  id                                              title  \
# 0           0   1  Betsy DeVos Confirmed as Education Secretary, ...
# 1           1   2  Melania Trump Says White House Could Mean Mill...
# 2           2   3  As Trump Fears Fraud, GOP Eliminates Election ...
# 3           3   4  Appeals Court to Decide on Challenge to Trump'...
# 4           4   5  At Least 4 Tornadoes Reported in Southeast Lou...
#
#                                              content   source  \
# 0  Michigan billionaire education activist Betsy ...  Harvard
# 1  First lady Melania Trump has said little about...  Harvard
# 2  A House committee voted on Tuesday to eliminat...  Harvard
# 3  This afternoon, three federal judges from the ...  Harvard
# 4  At least four tornadoes touched down in Louisi...  Harvard
#
#                                      title_true_case
# 0  Betsy Devos confirmed as education Secretary, ...
# 1  Melania Trump says White House could mean mill...
# ...

# %%
stop_words = ["christ","crucifix","church","pastor","priest",
              "god","islam","muslim","mullah","rabbi","jew","mosque","synagogue",
              "sex","rape","rapist","kill","hurrican","jihad","terror"
             "murder","victim","shoot","die","death","genocide",
             "homicid","suicid","violence","shoot","tortur","slave",
             "pedophil","maniac","racist","racism","feminism","feminist",
             "black lives matter","hate","assassin","death","immigrant","immigration",
             "holocaust","surviv","attack","accident","protest","shot","gun","molest",
             "abus","harass"]

# %%
sum([True,True])
# Out:
# 2

# %%
tqdm.pandas()
# Out:
# c:\users\k1l77\desktop\182e~1\term_p~1\lib\site-packages\tqdm\std.py:699: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %%
df['no_stop_words'] = df['title'].progress_apply(lambda x: sum([stop_word in x.lower() for stop_word in stop_words])==0)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 360637/360637 [00:08<00:00, 43747.35it/s]

# %%
df['no_stop_words'].value_counts()
# Out:
# True     300894
# False     59743
# Name: no_stop_words, dtype: int64

# %%
df = df[df['no_stop_words']==True]

# %%
len(df)
# Out:
# 300894

# %%
df
# Out:
#         Unnamed: 0      id                                              title  \
# 0                0       1  Betsy DeVos Confirmed as Education Secretary, ...
# 1                1       2  Melania Trump Says White House Could Mean Mill...
# 2                2       3  As Trump Fears Fraud, GOP Eliminates Election ...
# 4                4       5  At Least 4 Tornadoes Reported in Southeast Lou...
# 5                5       6  Mother of Backpacker Slain in Australia Critic...
# ...            ...     ...                                                ...
# 361191      361256  218078  An eavesdropping Uber driver saved his 16-year...
# 361192      361257  218079  Plane carrying six people returning from a Cav...
# 361193      361258  218080  After helping a fraction of homeowners expecte...
# 361194      361259  218081  Yes, this is real: Michigan just banned bannin...
# 361195      361260  218082  What happened in Washington state after voters...
#
# ...

# %%
df = df.drop(['no_stop_words'], axis=1)

# %%
df
# Out:
#         Unnamed: 0      id                                              title  \
# 0                0       1  Betsy DeVos Confirmed as Education Secretary, ...
# 1                1       2  Melania Trump Says White House Could Mean Mill...
# 2                2       3  As Trump Fears Fraud, GOP Eliminates Election ...
# 4                4       5  At Least 4 Tornadoes Reported in Southeast Lou...
# 5                5       6  Mother of Backpacker Slain in Australia Critic...
# ...            ...     ...                                                ...
# 361191      361256  218078  An eavesdropping Uber driver saved his 16-year...
# 361192      361257  218079  Plane carrying six people returning from a Cav...
# 361193      361258  218080  After helping a fraction of homeowners expecte...
# 361194      361259  218081  Yes, this is real: Michigan just banned bannin...
# 361195      361260  218082  What happened in Washington state after voters...
#
# ...

# %%
thousand_lines = df.sample(n=1000, random_state=42)

# %%
thousand_lines
# Out:
#         Unnamed: 0      id                                              title  \
# 142254      142316  162105  With Town Hall Script Flipped On GOP, Will His...
# 333042      333106  173644  As His Mother’s Multiple Sclerosis Progresses,...
# 351575      351640  205884  Rep. Steve King warns that ‘our civilization’ ...
# 207040      207103  247557  Dropbox Is Said to Be Planning to Go Public Th...
# 275416      275479   82255          Why Fewer Americans Outearn Their Parents
# ...            ...     ...                                                ...
# 159737      159799  184857  Exclusive: Microsoft to warn email users of su...
# 170737      170800  199846  Election results 2016: Donald Trump loses Wisc...
# 211602      211665  256195  John Kelly Pins Civil War on a ‘Lack of Abilit...
# 197546      197609  232516  Murray Hill, Manhattan: Where the Old and New ...
# 231476      231539   31585  Donald Trump Celebrates House Vote for Obamaca...
#
# ...

# %%
thousand_lines = thousand_lines.rename({"title_true_case": "headline"},
                                      axis=1)

# %%
thousand_lines.to_excel("1000Headlines.xlsx",engine="openpyxl")

# %%
thousand_lines
# Out:
#         Unnamed: 0      id                                              title  \
# 142254      142316  162105  With Town Hall Script Flipped On GOP, Will His...
# 333042      333106  173644  As His Mother’s Multiple Sclerosis Progresses,...
# 351575      351640  205884  Rep. Steve King warns that ‘our civilization’ ...
# 207040      207103  247557  Dropbox Is Said to Be Planning to Go Public Th...
# 275416      275479   82255          Why Fewer Americans Outearn Their Parents
# ...            ...     ...                                                ...
# 159737      159799  184857  Exclusive: Microsoft to warn email users of su...
# 170737      170800  199846  Election results 2016: Donald Trump loses Wisc...
# 211602      211665  256195  John Kelly Pins Civil War on a ‘Lack of Abilit...
# 197546      197609  232516  Murray Hill, Manhattan: Where the Old and New ...
# 231476      231539   31585  Donald Trump Celebrates House Vote for Obamaca...
#
# ...
